# %% [markdown]
# <a href="https://colab.research.google.com/github/CacheSync/ITAI-1371-ML-Labs/blob/main/L13_JustinTyler_ITAI1371.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.compose import ColumnTransformer, make_column_transformer

# Define preprocessing steps for numerical features
numeric_transformer = make_pipeline(
    SimpleImputer(strategy='median'), # Use imputer even if data is already filled, for consistency
    StandardScaler()
)

# Define preprocessing steps for categorical features
categorical_transformer = make_pipeline(
    SimpleImputer(strategy='most_frequent'), # For categorical missing values
    OneHotEncoder(handle_unknown='ignore')
)

# Create a preprocessor using ColumnTransformer
preprocessor = make_column_transformer(
    (numeric_transformer, numeric_features),
    (categorical_transformer, categorical_features)
)

# Create the full model pipeline
# The pipeline first applies the preprocessor, then trains a RandomForestClassifier
model_pipeline = make_pipeline(
    preprocessor,
    RandomForestClassifier(random_state=42)
)

# Train the model using the pipeline
model_pipeline.fit(X_train, y_train)

# Make predictions with the pipeline
y_pred_pipeline = model_pipeline.predict(X_test)

# Evaluate the model
print(f"Accuracy (Pipeline Method): {accuracy_score(y_test, y_pred_pipeline):.2%}")
# Out:
# Accuracy (Pipeline Method): 82.68%

# %% [markdown]
# 1.  Streamlined Workflow, Prevents Data Leakage, & Easier Hyperparameter Tuning and Model Deployment.
#
# 2.  It prevents data leakage.  By ensuring that the fit() method for all preprocessing steps is only called on the training data when you call model_pipeline.fit.
#
# 3.  Insert PCA() as a new step in the make_pipeline call for your model_pipeline
#
# 4.  Because of Zero Risk of Missing Artifacts or Desynchronization, Acceptance of Raw Input Data, and Elimination of Training-Serving Skew
